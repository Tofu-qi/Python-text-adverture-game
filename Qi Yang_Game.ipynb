# %%
# Introduction：This game is based on an ancient Chinese love story. Hope you enjoy it.
from sys import exit
import random
import time


def start():
    print("""
A senior official at the time of the southern song dynasty, named Dong,
his wife died, he wanted to draw a portrait for her, 
but it needs a special kind of paint, and this kind of pigment exists 
in Du's handkerchief, so in order to get that, he sent a name is Wang to 
find a way to, and agreed to give him gold after the job is done.
""")
    input("<Press enter to continue>\n")
    room_1()


# The first act
def room_1():
    print("""
      A pretty young girl is washing clothes by the river, singing and wiping 
      the sweat from her forehead with her handkerchief now and then. 
      This picture is very beautiful, attracted the Tang starings at the girl 
      on the other side of the river, forgets to stare at a girl so very impolite. 
      Was ready to take back his eyes, but was found by the girl, 
      the girl shy and panic, got up and ran home quickly...... 
    
      Unexpectedly, the handkerchief fell on the river.
        """)

    input("<Press enter to continue>\n")

    print("""
    ✨Are you going to pick up the handkerchief for the girl and give it back to her?
    
    Y or N
    """)

    choice_0 = input("")

    if "y" in choice_0.lower():
        print("""You walk across the river, pick up the handkerchief, and run in the direction of the girl""")
        input("<Press enter to continue>\n")
    elif "n" in choice_0.lower():
        print("""I'm sorry that you missed your love because of your inaction""")

        fail()
    else:
        fail()

    print("""You come to a fork in the road, you do not know which road you should choose, 
    ✨you see the roadside stall aunt, do you ask?
    
    Y or N
    """)

    choice_1 = input("")

    if "y" in choice_1.lower():
        print("""Hello, the girl went down the lane to the left.""")
        input("<Press enter to continue>\n")
    elif "n" in choice_1.lower():
        print("""Lazy people are not worthy of love.🤷‍♀️""")

        fail()
    else:
        fail()

    print("""Tang quickened his pace, ran down the alley to his left, and finally saw the girl not far away.""")
    input("<Press enter to continue>\n")

    print("""Tang shouted："Girl, don't run away, I'm not a bad guy, I'm just returning your handkerchief!"
    
    The girl stopped and felt in her pocket. The handkerchief was indeed gone. 
    
    When Tang saw the girl stop, he ran quickly to her.
    """)

    print("""Tang handed the handkerchief to the girl, who saluted him and said, "Thank you, Sir." 
    
    ✨What does Tang have to say when he wants to apologize for his rude behavior when he just stared at a girl?
    """)
    input('')
    print("""The girl saw Tang's sincere attitude and forgave him.""")

    print("""✨What's the name of the Male role？""")
    name = input("The Male role's name: \n")
    print(f""" "Thank you girl, my name is {name}, may I have your name?" """)
    input("<Press enter to continue>\n")
    print("""My name is Du, the girl replied.""")
    input("<Press enter to continue>\n")

    print("""The two talked happily, knowing that each other liked Opera, 
    they decided to go to the outskirts of the "The Peony Pavilion" to discuss together, 
    Tang wrote the lyrics, Du sang.
    """)
    room_2()


# The second act
def room_2():
    print('===' * 40)
    print("""On the other side, Wang went directly to Du's house and met her aunt. 
    Du had no parents since she was a child, and it was her aunt who raised her. 
    Wang knew that Du's aunt is a money-hungry person, he told his aunt, 
    he has a long love of Du, personally come to ask for marriage, the betrothed gift is 20 gold.""")
    input("<Press enter to continue>\n")

    print("""✨What do you think aunt will do?
    
    1.Agree the Wang's offer directly
    2.Wait for Du to come back and ask questions before making a decision
    """)
    choice_2 = input()
    if "1" in choice_2:
        print("""Aunt said: "Marriage matters, the elders make the decision, I will give Du to you!" """)
        input("<Press enter to continue>\n")
    else:
        print("""Unfortunately, aunt is fall in love with money, in front of money she 
        always choose money.
        """)
        fail()
    room_3()


# The third act
def room_3():
    print("""Tang and Du get along very well in the Peony pavilion, 
    Du was deeply attracted by Tang's talent, Tang also fell in love at first sight to Du. 
    """)
    input("<Press enter to continue>\n")

    print(""" Tang said："I don't know whether to say this or not, but I want to marry 
    and take care of you for the rest of my life." 
    Du did not expect that and shyly put the handkerchief into his hand. 
    
    Now you need to answer one question.
    """)

    question_list = ['✨Why did Du give Her handkerchief to Tang?',
                     '✨Where do Tang and Du discuss Opera?']
    questions = 1
    while questions > 0:
        question = random.choice(question_list)
        input("<Press enter for your question>")
        print(question)

        if question == question_list[0]:
            print("1) A handkerchief is a token of affection.")
            print("2) She wanted to wipe Tang's sweat.")
            print("3) She rejected Tang.")

            answer = input("")

            if answer == '1':
                print("""Yes! You are soooo clever！
                           Since you answered the question correctly, Tang can go to Du's family to propose.
    
                    😊Tips:In ancient China, a handkerchief was a girl's personal 
                     thing, and only a man who decided to get married could give it 
                     to him as a pledge of love between two people.""")
                questions -= 1
                room_4()
                break
            else:
                print("Come one, thinking again.")
                fail()
                break
        elif question == question_list[1]:
            print("1) Beijing.")
            print("2) Shanghai.")
            print("3) The Peony Pavilion.")
            answer = input("")
            if answer == '3':
                print("Yes! You are soooo clever，Since you answered the question correctly, Tang can go to Du's family to propose. 😊")
                room_4()
                break
            else:
                print("Come one, thinking again.")
                fail()
                break


# The fourth act
def room_4():
    print(""" "✨Du,where is your home?" """)
    print(""" "Your fifth from the left is my home." """)
    input("<Press enter for count>\n")
    count = 5
    while count > 0:
        print(count)
        count = count - 1
        time.sleep(1)
    print("Got it!")
    print("""Tang and Du arrived at home, only to know that her aunt had married 
    Du to Wang, but Du has his handkerchief as a token of love to Tang.
    At this time, Wang realized that the biggest obstacle on his way is Tang, so he wants to kill him.😈
    
    Du noticed that Wang take out his knife and stab Tang.
    
    ✨If you are Du, do you want to save Tang?
    Y or N
    """)
    choice_fin = input()

    if "y" in choice_fin.lower():
        print("""Du for Tang blocked a fatal knife, died on the spot. Tang holding the dead Du sobbed, 
        rushed to the scene of Dong also pretended not to accept Du's relics, 
        but Tang said the lover is not in, relics have no meaning, 
        so Dong took the handkerchief.
        Tang turned his love affair with Du into a opera called "The Peony Pavilion".
        """)
        time.sleep(1)
        print('Win!!!')
        exit(0)
    else:
        print("""When Tang dies, Du marry Wang who does not truly love her. 
        Wang completes the task of Dong and gets a reward.Aunt also got the gold.""")
        fail()


def fail():
    print("Sorry,you failed.")
    input('<Game Over>')

    exit(0)


start()
# Out:
# <Press enter to continue>
#
#
#   A pretty young girl is washing clothes by the river, singing and wiping
#   the sweat from her forehead with her handkerchief now and then.
#   This picture is very beautiful, attracted the Tang starings at the girl
#   on the other side of the river, forgets to stare at a girl so very impolite.
#   Was ready to take back his eyes, but was found by the girl,
#   the girl shy and panic, got up and ran home quickly......
#
#   Unexpectedly, the handkerchief fell on the river.
#
# <Press enter to continue>
#
#
# ✨Are you going to pick up the handkerchief for the girl and give it back to her?
#
# Y or N
#
# Y
# You walk across the river, pick up the handkerchief, and run in the direction of the girl
# <Press enter to continue>
#
# You come to a fork in the road, you do not know which road you should choose,
# ✨you see the roadside stall aunt, do you ask?
#
# Y or N
#
# Y
# Hello, the girl went down the lane to the left.
# <Press enter to continue>
#
# ...
